# %% [markdown]
# ## Standardized tool

# %% [markdown]
# ### 1.3GS_sequence

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/3GS_sequence/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/3GS_sequence/rs/seq/ \
    -key .jpg \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/3GS_sequence/
# 100%|████████████████████████████████████████| 259/259 [00:00<00:00, 399.88it/s]
# standardized sucess!

# %% [markdown]
# ### 2.Carcam

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carcam/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Carcam/rs/seq/ \
    -key .png \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carcam/
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 57.44it/s]
# standardized sucess!

# %% [markdown]
# ### 3.Carla_rs_test

# %% [markdown]
# - RS

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Carla_rs_test/rs/ \
    -key _rs.png \
    --seq True \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_36
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 114.16it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_0
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 116.24it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_1
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 139.48it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_11
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 97.40it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_12
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 129.51it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_13
# ...

# %% [markdown]
# - GS

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Carla_rs_test/gs/ \
    -key gs_m.png \
    --seq True \
    --model cp \
    --prefix gs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_36
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 31.31it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_0
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 34.73it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_1
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 33.86it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_11
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 33.95it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_12
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 32.37it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Carla_rs_test/seq_13
# ...

# %% [markdown]
# ## 4.Fastec_rs_test

# %% [markdown]
# - RS

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Fastec_rs_test/rs/ \
    -key rolling.png \
    --seq True \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000004
# 100%|███████████████████████████████████████████| 34/34 [00:01<00:00, 27.69it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000009
# 100%|███████████████████████████████████████████| 32/32 [00:00<00:00, 37.62it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000010
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 39.56it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000011
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 43.57it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000013
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 39.54it/s]
# standardized sucess!
# ...

# %% [markdown]
# - GS

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Fastec_rs_test/gs/ \
    -key global_middle.png \
    --seq True \
    --model cp \
    --prefix gs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000004
# 100%|███████████████████████████████████████████| 34/34 [00:01<00:00, 32.30it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000009
# 100%|███████████████████████████████████████████| 32/32 [00:00<00:00, 41.19it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000010
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 43.10it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000011
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 41.50it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Fastec_rs_test/190206_Tuebingen_000013
# 100%|███████████████████████████████████████████| 34/34 [00:00<00:00, 44.09it/s]
# standardized sucess!
# ...

# %% [markdown]
# ### 5.Grant_Park

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Grant_Park/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/Grant_Park/rs/seq/ \
    -key .jpg \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/Grant_Park/
# 100%|█████████████████████████████████████████| 179/179 [00:02<00:00, 67.53it/s]
# standardized sucess!

# %% [markdown]
# ### 6.House

# %%
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_rot1_B0/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_rot1_B20/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_rot1_B40/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_rot2_B40/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_trans_rot1_B40/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/House/rs/house_trans1_B40/ \
    -key .png \
    --model cp \
    --prefix rs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 42.29it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 138.49it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 185.38it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 178.07it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/House/house_rot1_B0/rolling_shutter/
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 168.55it/s]
# standardized sucess!
# ...

# %% [markdown]
# ### 6.IMU_test

# %%
# seq1
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq1/images/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/rs/seq1/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq1/images_gs/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/gs/seq1/ \
    -key .png \
    --model cp \
    --prefix gs_

# seq3
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq3/images/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/rs/seq3/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq3/images_gs/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/gs/seq3/ \
    -key .png \
    --model cp \
    --prefix gs_

# seq6
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq6/images/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/rs/seq6/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq7/images_gs/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/gs/seq6/ \
    -key .png \
    --model cp \
    --prefix gs_

# seq7
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq7/images/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/rs/seq7/ \
    -key .png \
    --model cp \
    --prefix rs_

# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq7/images_gs/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/IMU_test/gs/seq7/ \
    -key .png \
    --model cp \
    --prefix gs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq1/images/
# 100%|███████████████████████████████████████████| 72/72 [00:01<00:00, 58.37it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq1/images_gs/
# 100%|███████████████████████████████████████████| 72/72 [00:01<00:00, 64.68it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq3/images/
# 100%|█████████████████████████████████████████| 192/192 [00:03<00:00, 60.33it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq3/images_gs/
# 100%|█████████████████████████████████████████| 192/192 [00:03<00:00, 60.99it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/IMU/IMU_test/seq6/images/
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 57.08it/s]
# standardized sucess!
# ...

# %% [markdown]
# ### 7.rsvi_t1_fast

# %%
# rs
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rsvi_t1_fast/rs/clean/img/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/rsvi_t1_fast/rs/clean/ \
    -key .png \
    --model cp \
    --prefix rs_

# gs
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rsvi_t1_fast/gs/clean/img/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/rsvi_t1_fast/gs/clean/ \
    -key .png \
    --model cp \
    --prefix gs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rsvi_t1_fast/rs/clean/img/
# 100%|█████████████████████████████████████████| 825/825 [00:25<00:00, 31.92it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rsvi_t1_fast/gs/clean/img/
# 100%|█████████████████████████████████████████| 825/825 [00:27<00:00, 29.81it/s]
# standardized sucess!

# %% [markdown]
# ### 8.rscd

# %%
# rs
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/rscd_test/rs/ \
    -key .png \
    --seq True \
    --model cp \
    --prefix rs_

# gs
# !python standardized.py \
    -root /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/global/ \
    -target /media/qdl/LENOVO_USB_HDD1/Dataset/RS_clean/rscd_test/gs/ \
    -key .png \
    --seq True \
    --model cp \
    --prefix gs_
# Out:
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/000
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 38.21it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/001
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 43.28it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/002
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 32.42it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/003
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 32.65it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/004
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 40.09it/s]
# standardized sucess!
# standardized /media/qdl/LENOVO_USB_HDD1/Dataset/RS/rscd/test/rolling/005
# ...
